# %% [markdown]
# Import packages and construct list of DEMs (stored in dems var).

# %%
from pathlib import Path
import topotoolbox as tt
import matplotlib.pyplot as plt

rasterFolder = Path('Snow Depth Rasters')
dems = []

#loop through each file in rasters folder
for file in rasterFolder.iterdir():

    #ensure file is .tif
    if not file.is_file() or file.suffix.lower() != '.tif': false
    
    dateStr = file.name[3:9]
    dem = tt.read_tif(file)
    dems.append(dem)

# %%
print(len(dems))
for dem in dems:
    print(dem.info())
